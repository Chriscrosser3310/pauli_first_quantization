# %%
import importlib.metadata as md
import ipywidgets
print("ipywidgets:", ipywidgets.__version__)
print("ipyforcegraph:", md.version("ipyforcegraph"))
from ipyforcegraph.graphs import ForceGraph3D
FG = ForceGraph3D(); FG.graph = {"nodes":[{"id":"a"}], "links":[]}
display(FG)
# Out:
# ipywidgets: 8.1.7
# ipyforcegraph: 0.4.1
# ForceGraph3D(source=DataFrameSource(nodes=(0, 0), links=(0, 0)))
